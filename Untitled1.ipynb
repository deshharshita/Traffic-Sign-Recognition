# %%
# %run traffic_sign.py
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\Desktop\Traffic sign classification\traffic_sign.py in <module>
#       3 import matplotlib.pyplot as plt
#       4 import cv2
# ----> 5 import tensorflow as tf
#       6 from PIL import Image
#       7 import os
#
# G:\Anaconda\lib\site-packages\tensorflow\__init__.py in <module>
#     471 if hasattr(_current_module, "keras"):
#     472   try:
# --> 473     keras._load()
#     474   except ImportError:
#     475     pass
#
# G:\Anaconda\lib\site-packages\tensorflow\python\util\lazy_loader.py in _load(self)
#      39     """Load the module and insert it into the parent's globals."""
#      40     # Import the target module and insert it into the parent's namespace
# ---> 41     module = importlib.import_module(self.__name__)
#      42     self._parent_module_globals[self._local_name] = module
#      43
#
# ...

# %%
# %run traffic_sign.py
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\Desktop\Traffic sign classification\traffic_sign.py in <module>
#       3 import matplotlib.pyplot as plt
#       4 import cv2
# ----> 5 import tensorflow as tf
#       6 from PIL import Image
#       7 import os
#
# G:\Anaconda\lib\site-packages\tensorflow\__init__.py in <module>
#     471 if hasattr(_current_module, "keras"):
#     472   try:
# --> 473     keras._load()
#     474   except ImportError:
#     475     pass
#
# G:\Anaconda\lib\site-packages\tensorflow\python\util\lazy_loader.py in _load(self)
#      39     """Load the module and insert it into the parent's globals."""
#      40     # Import the target module and insert it into the parent's namespace
# ---> 41     module = importlib.import_module(self.__name__)
#      42     self._parent_module_globals[self._local_name] = module
#      43
#
# ...

# %%
# %run traffic_sign.py
